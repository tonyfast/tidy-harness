# %%
from IPython import display, get_ipython

# %%
# !pyreverse harness -f ALL -o png
# Out:
# parsing /Users/tonyfast/tidy-harness/harness/__init__.py...
# parsing /Users/tonyfast/tidy-harness/harness/__init__.py...
# parsing /Users/tonyfast/tidy-harness/harness/base.py...
# parsing /Users/tonyfast/tidy-harness/harness/environment.py...
# parsing /Users/tonyfast/tidy-harness/harness/harness.py...
# parsing /Users/tonyfast/tidy-harness/harness/ext/__init__.py...
# parsing /Users/tonyfast/tidy-harness/harness/ext/base.py...
# parsing /Users/tonyfast/tidy-harness/harness/ext/Bokeh.py...
# parsing /Users/tonyfast/tidy-harness/harness/ext/SciKit.py...

# %%
display.Image("""classes_No_Name.png""", embed=True)

# %%
display.Image("""packages_No_Name.png""", embed=True)

# %%
# %rm classes_No_Name.png
# %rm packages_No_Name.png
